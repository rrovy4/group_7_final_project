# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Resources/KSI.csv')

# %%
pd.set_option('display.max_columns', None)
data
# Out:
#                   X             Y    INDEX_   ACCNUM  YEAR  \
# 0     -8.844611e+06  5.412414e+06   3387730   892658  2006
# 1     -8.844611e+06  5.412414e+06   3387731   892658  2006
# 2     -8.816480e+06  5.434843e+06   3388101   892810  2006
# 3     -8.816480e+06  5.434843e+06   3388102   892810  2006
# 4     -8.822759e+06  5.424516e+06   3387793   892682  2006
# ...             ...           ...       ...      ...   ...
# 16855 -8.820837e+06  5.421411e+06  81509784  1636966  2020
# 16856 -8.820068e+06  5.425334e+06  81505452  1650701  2020
# 16857 -8.820068e+06  5.425334e+06  81505453  1650701  2020
# 16858 -8.820068e+06  5.425334e+06  81505454  1650701  2020
# 16859 -8.842562e+06  5.412998e+06  81509748  1650875  2020
#
#                          DATE  TIME  HOUR          STREET1           STREET2  \
# 0      2006/03/11 05:00:00+00   852     8       BLOOR ST W       DUNDAS ST W
# 1      2006/03/11 05:00:00+00   852     8       BLOOR ST W       DUNDAS ST W
# ...

# %%
data.replace('<Null>', np.nan, inplace=True)

# %%
data.head()
# Out:
#               X             Y   INDEX_  ACCNUM  YEAR                    DATE  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658  2006  2006/03/11 05:00:00+00
# 1 -8.844611e+06  5.412414e+06  3387731  892658  2006  2006/03/11 05:00:00+00
# 2 -8.816480e+06  5.434843e+06  3388101  892810  2006  2006/03/11 05:00:00+00
# 3 -8.816480e+06  5.434843e+06  3388102  892810  2006  2006/03/11 05:00:00+00
# 4 -8.822759e+06  5.424516e+06  3387793  892682  2006  2006/03/12 05:00:00+00
#
#    TIME  HOUR          STREET1           STREET2 OFFSET      ROAD_CLASS  \
# 0   852     8       BLOOR ST W       DUNDAS ST W    NaN  Major Arterial
# 1   852     8       BLOOR ST W       DUNDAS ST W    NaN  Major Arterial
# 2   915     9  MORNINGSIDE AVE    SHEPPARD AVE E    NaN  Major Arterial
# 3   915     9  MORNINGSIDE AVE    SHEPPARD AVE E    NaN  Major Arterial
# 4   240     2   EGLINTON AVE E  COMMONWEALTH AVE    NaN  Major Arterial
#
# ...

# %%
data.groupby('DISTRICT')['NEIGHBOURHOOD'].nunique()
# Out:
# DISTRICT
# Etobicoke York           52
# North York               68
# Scarborough              35
# Toronto East York        15
# Toronto and East York    56
# Name: NEIGHBOURHOOD, dtype: int64

# %%
 data.groupby('POLICE_DIVISION')['NEIGHBOURHOOD'].nunique()
# Out:
# POLICE_DIVISION
# D11    12
# D12    11
# D13    13
# D14    12
# D22    15
# D23    11
# D31     7
# D32    18
# D33    14
# D41    10
# D42     9
# D43    11
# D51     8
# D52     6
# D53    16
# D54    12
# D55    10
# Name: NEIGHBOURHOOD, dtype: int64

# %%
# data_new = data.groupby(['POLICE_DIVISION'])['ACCLASS']

# %%
# data_new.head()
# Out:
# 0                 Fatal
# 1                 Fatal
# 2                 Fatal
# 3                 Fatal
# 4                 Fatal
#              ...
# 154    Non-Fatal Injury
# 208    Non-Fatal Injury
# 211    Non-Fatal Injury
# 233    Non-Fatal Injury
# 311    Non-Fatal Injury
# Name: ACCLASS, Length: 85, dtype: object

# %%
data.groupby('POLICE_DIVISION')['ACCLASS'].nunique()
# Out:
# POLICE_DIVISION
# D11    2
# D12    2
# D13    2
# D14    2
# D22    2
# D23    2
# D31    2
# D32    2
# D33    2
# D41    2
# D42    2
# D43    3
# D51    2
# D52    2
# D53    2
# D54    2
# D55    2
# Name: ACCLASS, dtype: int64

# %%
acclass_data = pd.DataFrame(data.groupby(['POLICE_DIVISION', 'ACCLASS'])['ACCNUM'].count())

# %%
acclass_data.head(50)
# Out:
#                                       ACCNUM
# POLICE_DIVISION ACCLASS
# D11             Fatal                    111
#                 Non-Fatal Injury         698
# D12             Fatal                     62
#                 Non-Fatal Injury         675
# D13             Fatal                     86
#                 Non-Fatal Injury         708
# D14             Fatal                    119
#                 Non-Fatal Injury        1044
# D22             Fatal                    129
#                 Non-Fatal Injury        1073
# D23             Fatal                    208
#                 Non-Fatal Injury         956
# D31             Fatal                    137
#                 Non-Fatal Injury         741
# D32             Fatal                    189
#                 Non-Fatal Injury        1004
# D33             Fatal                    133
#                 Non-Fatal Injury         718
# D41             Fatal                    253
# ...

# %%
acclass_data.to_csv('acclass_division.csv')

# %%
date_data = data['DATE']

# %%
date_data
# Out:
# 0        2006/03/11 05:00:00+00
# 1        2006/03/11 05:00:00+00
# 2        2006/03/11 05:00:00+00
# 3        2006/03/11 05:00:00+00
# 4        2006/03/12 05:00:00+00
#                   ...
# 16855    2020/08/30 04:00:00+00
# 16856    2020/09/01 04:00:00+00
# 16857    2020/09/01 04:00:00+00
# 16858    2020/09/01 04:00:00+00
# 16859    2020/09/01 04:00:00+00
# Name: DATE, Length: 16860, dtype: object

# %%
date_data = [i[:10] for i in date_data]

# %%
date_data
# Out:
# ['2006/03/11',
#  '2006/03/11',
#  '2006/03/11',
#  '2006/03/11',
#  '2006/03/12',
#  '2006/03/12',
#  '2006/03/12',
#  '2006/03/12',
#  '2006/03/12',
#  '2006/03/15',
#  '2006/03/15',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/16',
#  '2006/03/17',
#  '2006/03/17',
#  '2006/03/17',
#  '2006/03/17',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/18',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/19',
#  '2006/03/20',
#  '2006/03/20',
#  '2006/03/20',
#  '2006/03/20',
#  '2006/03/20',
#  '2006/03/22',
#  '2006/03/22',
#  '2006/03/22',
#  '2006/03/25',
#  '2006/03/25',
#  '2006/03/25',
#  '2006/03/25',
#  '2006/03/25',
#  '2006/03/25',
#  '2006/03/25',
# ...

# %%
for id, i in enumerate(data['DATE']):
	data.at[id, 'DATE'] = data['DATE'][id][:10]

# %%
data
# Out:
#                   X             Y    INDEX_   ACCNUM  YEAR        DATE  TIME  \
# 0     -8.844611e+06  5.412414e+06   3387730   892658  2006  2006/03/11   852
# 1     -8.844611e+06  5.412414e+06   3387731   892658  2006  2006/03/11   852
# 2     -8.816480e+06  5.434843e+06   3388101   892810  2006  2006/03/11   915
# 3     -8.816480e+06  5.434843e+06   3388102   892810  2006  2006/03/11   915
# 4     -8.822759e+06  5.424516e+06   3387793   892682  2006  2006/03/12   240
# ...             ...           ...       ...      ...   ...         ...   ...
# 16855 -8.820837e+06  5.421411e+06  81509784  1636966  2020  2020/08/30  1340
# 16856 -8.820068e+06  5.425334e+06  81505452  1650701  2020  2020/09/01  1205
# 16857 -8.820068e+06  5.425334e+06  81505453  1650701  2020  2020/09/01  1205
# 16858 -8.820068e+06  5.425334e+06  81505454  1650701  2020  2020/09/01  1205
# 16859 -8.842562e+06  5.412998e+06  81509748  1650875  2020  2020/09/01  1238
#
# ...

# %%
data.groupby('DATE')['ACCNUM'].nunique()
# Out:
# DATE
# 2006/01/01    2
# 2006/01/02    1
# 2006/01/04    1
# 2006/01/06    1
# 2006/01/07    1
#              ..
# 2020/12/20    1
# 2020/12/21    1
# 2020/12/25    1
# 2020/12/27    1
# 2020/12/30    2
# Name: ACCNUM, Length: 3549, dtype: int64

# %%
date_accnum_data = pd.DataFrame(data.groupby(['DATE', 'ACCLASS'])['ACCNUM'].count())

# %%
date_accnum_data
# Out:
#                              ACCNUM
# DATE       ACCLASS
# 2006/01/01 Non-Fatal Injury      13
# 2006/01/02 Non-Fatal Injury       2
# 2006/01/04 Non-Fatal Injury       2
# 2006/01/06 Non-Fatal Injury       2
# 2006/01/07 Fatal                  3
# ...                             ...
# 2020/12/21 Non-Fatal Injury       2
# 2020/12/25 Non-Fatal Injury       2
# 2020/12/27 Non-Fatal Injury       4
# 2020/12/30 Fatal                  2
#            Non-Fatal Injury       2
#
# [3989 rows x 1 columns]

# %%
date_accnum_data.to_csv('date_accnum.csv')

# %%
date_accnum_data_new = pd.DataFrame(data.groupby(['DATE', 'ACCLASS', 'INJURY'])['ACCNUM'].count())

# %%
date_accnum_data_new
# Out:
#                                     ACCNUM
# DATE       ACCLASS          INJURY
# 2006/01/01 Non-Fatal Injury Major        2
#                             Minor        7
#                             None         2
# 2006/01/02 Non-Fatal Injury Major        1
#                             None         1
# ...                                    ...
# 2020/12/27 Non-Fatal Injury None         1
# 2020/12/30 Fatal            Fatal        1
#                             None         1
#            Non-Fatal Injury Major        1
#                             None         1
#
# [8956 rows x 1 columns]

# %%
date_accnum_data_new.to_csv('date_accnum_injury.csv')

# %%
time_accnum_data = pd.DataFrame(data.groupby(['HOUR', 'ACCLASS'])['ACCNUM'].count())

# %%
time_accnum_data
# Out:
#                            ACCNUM
# HOUR ACCLASS
# 0    Fatal                     91
#      Non-Fatal Injury         466
# 1    Fatal                     64
#      Non-Fatal Injury         344
# 2    Fatal                     72
#      Non-Fatal Injury         391
#      Property Damage Only       2
# 3    Fatal                     50
#      Non-Fatal Injury         371
# 4    Fatal                     25
#      Non-Fatal Injury         147
# 5    Fatal                     80
#      Non-Fatal Injury         206
# 6    Fatal                     98
#      Non-Fatal Injury         414
# 7    Fatal                     78
#      Non-Fatal Injury         465
# 8    Fatal                     68
#      Non-Fatal Injury         600
# 9    Fatal                    112
#      Non-Fatal Injury         574
# 10   Fatal                    108
#      Non-Fatal Injury         615
# 11   Fatal                    107
#      Non-Fatal Injury         607
# 12   Fatal                    104
# ...

# %%
time_accnum_data.to_csv('time_accnum.csv')
